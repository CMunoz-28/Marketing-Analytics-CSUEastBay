# %% [markdown]
# #Marketing Analytics & Statistical Analysis
#
# ##Data Analysis - BUHI Supply Co.
#
# ###Perform Data Analysis on dataset "Optimize for Revenue.csv"
#
# ####Dataset: Provided by [Stukent](https://www.stukent.com/) | Digital Marketing Analytics Simternship - California State Univeristy, East Bay

# %% [markdown]
# ###Objectives
# Leverage historical campaign data and allocate a budget of $20,000 to help maximize revenue growth, while also ensuring cost-effective investments in performance upgrades that enhance marketing efficiency.
#
#
# ####Key areas:
#
# * Understand campaign performance trends across key metrics like clicks, impressions, CPC, and Cost.
#
# * Identify top-performing campaigns in terms of both efficiency (low CPC) and effectiveness (high clicks).
#
# * Allocate a $20,000 budget to campaigns to maximize revenue.
#
# * Use CPC (Cost-Per-Click) metrics to predict outcomes from allocated budgets.
#
# * Prioritize campaigns that offer the most cost-effective clicks.
#
# ####Constraints:
# * No more than $3,000 allocated to any single campaign. Consider each campaign’s recommended budget max.

# %% [markdown]
# ##Libraries, Directory, Data
#
# Our data consists of one .csv file containing the following data types:
#
# * Campaign
# * Campaign Type
# * Source (Paid, Owned, Earned Media)
# * Clicks
# * Impressions
# * Cost
# * Click-Through-Rate (CTR)
# * Input Budget
# * Recommended Budget Max

# %%
#Change the Directory
# %cd /content/drive/MyDrive/Assignments/Stukent - Data Analysis | Seminar in Digital Mktg/Revenue
# Out:
# /content/drive/MyDrive/Assignments/Stukent - Data Analysis | Seminar in Digital Mktg/Revenue

# %%
#Install needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
revenue_df = pd.read_csv('Optimize_for_Revenue.csv')
revenue_df.head()
# Out:
#   Campaign Type       Source         Campaign  Input Budget  \
# 0     Affiliate    Clickbank             Tote           112
# 1     Affiliate    Clickbank          Satchel           108
# 2     Affiliate    Clickbank            Purse           126
# 3     Affiliate   Shareasale            Purse           151
# 4       Display  Retargeting  Yellow Backpack           295
#
#    Cost per Impression  Impressions   CTR  Clicks   CPC  Cost  \
# 0                 0.04         2811  0.01      24  4.40   104
# 1                 0.04         2513  0.01      28  3.55    98
# 2                 0.04         3486  0.01      32  3.85   122
# 3                 0.03         5560  0.01      37  3.73   139
# 4                 0.01        35750  0.00      39  7.27   286
#
#    Recommended Budget Max  Conversions  CPA (Cost Per Conversion)  \
# 0                  2657.0            2                      52.00
# 1                  1489.0            1                      98.00
# ...

# %% [markdown]
# #Data Analysis

# %%
# Calculate the average revenue and average cost per campaign
average_revenue = revenue_df['Revenue'].mean()
average_cost = revenue_df['Cost'].mean()

average_revenue, average_cost
# Out:
# (604.7583333333333, 210.51666666666668)

# %% [markdown]
# The average revenue per campaign is approximately **\$604.76**, and the average cost per campaign is approximately **\$210.52**.

# %%
# Identify the campaign with the highest revenue and its cost
highest_revenue_campaign = revenue_df.loc[revenue_df['Revenue'].idxmax()]

highest_revenue_campaign[['Campaign', 'Revenue', 'Cost']]
# Out:
# Campaign    Satchel
# Revenue        4710
# Cost            279
# Name: 119, dtype: object

# %% [markdown]
# The campaign that generated the highest revenue is "Satchel", with a revenue of **$4,710** and a cost of **\$279**.

# %%
# Identify the campaign with the least revenue and its cost
lowest_revenue_campaign = revenue_df.loc[revenue_df['Revenue'].idxmin()]

lowest_revenue_campaign[['Campaign', 'Revenue', 'Cost']]
# Out:
# Campaign    Handbag
# Revenue          33
# Cost            117
# Name: 9, dtype: object

# %% [markdown]
# The campaign that generated the least revenue is "**Handbag**", with a revenue of **$33** and a cost of **\$117**.

# %%
# Check the source of the "Handbag" campaign
lowest_revenue_campaign['Source']
# Out:
# 'LinkedIn'

# %% [markdown]
# The "**Handbag**" campaign was run on **LinkedIn**.

# %%
# Identify the campaign with the highest cost and its revenue
highest_cost_campaign = revenue_df.loc[revenue_df['Cost'].idxmax()]

highest_cost_campaign[['Campaign', 'Cost', 'Revenue']]
# Out:
# Campaign    Travel Bag
# Cost               298
# Revenue             88
# Name: 76, dtype: object

# %% [markdown]
# The campaign with the highest cost is "**Travel Bag**", which incurred a cost of **$298** and generated a revenue of **\$88**.

# %%
# Calculate the overall revenue per conversion
total_revenue = revenue_df['Revenue'].sum()
total_conversions = revenue_df['Conversions'].sum()
revenue_per_conversion = total_revenue / total_conversions

revenue_per_conversion
# Out:
# 119.95206611570248

# %% [markdown]
# The overall revenue generated per conversion is approximately **$119.95**.

# %%
# Calculate revenue per conversion for each campaign
revenue_df['Revenue per Conversion'] = revenue_df['Revenue'] / revenue_df['Conversions']

# Identify the campaign with the highest revenue per conversion
highest_revenue_per_conversion_campaign = revenue_df.loc[revenue_df['Revenue per Conversion'].idxmax()]

highest_revenue_per_conversion_campaign[['Campaign', 'Revenue per Conversion', 'Revenue', 'Conversions']]
# Out:
# Campaign                  Pouch
# Revenue per Conversion    200.0
# Revenue                    1400
# Conversions                   7
# Name: 88, dtype: object

# %% [markdown]
# The campaign with the highest revenue per conversion is "**Pouch**", with a revenue per conversion of **\$200.00**, a total revenue of **$1,400**, and **7** **conversions**.

# %%
# Identify the campaign with the lowest revenue per conversion
lowest_revenue_per_conversion_campaign = revenue_df.loc[revenue_df['Revenue per Conversion'].idxmin()]

lowest_revenue_per_conversion_campaign[['Campaign', 'Revenue per Conversion', 'Revenue', 'Conversions']]
# Out:
# Campaign                  Yellow Backpack
# Revenue per Conversion               25.0
# Revenue                               150
# Conversions                             6
# Name: 25, dtype: object

# %% [markdown]
# The campaign with the lowest revenue per conversion is "**Yellow Backpack**", with a revenue per conversion of **$25.00**, a total revenue of **\$150**, and **6 conversions.**

# %%
# Calculate the overall revenue per dollar spent
revenue_per_dollar_spent = total_revenue / revenue_df['Cost'].sum()

revenue_per_dollar_spent
# Out:
# 2.872733750296889

# %% [markdown]
# The overall revenue generated per dollar spent is approximately **$2.87**

# %%
# Calculate revenue per dollar spent for each campaign
revenue_df['Revenue per Dollar Spent'] = revenue_df['Revenue'] / revenue_df['Cost']

# Identify the campaign with the highest revenue per dollar spent
highest_revenue_per_dollar_campaign = revenue_df.loc[revenue_df['Revenue per Dollar Spent'].idxmax()]

highest_revenue_per_dollar_campaign[['Campaign', 'Revenue per Dollar Spent', 'Revenue', 'Cost']]
# Out:
# Campaign                     Satchel
# Revenue per Dollar Spent    16.88172
# Revenue                         4710
# Cost                             279
# Name: 119, dtype: object

# %% [markdown]
# The campaign that generated the most revenue per dollar spent is "**Satchel**", with a revenue per dollar spent of approximately **\$16.88**, a total revenue of **$4,710**, and a cost of **\$279**

# %%
# Identify the campaign with the lowest revenue per dollar spent
lowest_revenue_per_dollar_campaign = revenue_df.loc[revenue_df['Revenue per Dollar Spent'].idxmin()]

lowest_revenue_per_dollar_campaign[['Campaign', 'Revenue per Dollar Spent', 'Revenue', 'Cost']]
# Out:
# Campaign                    Rolling Bag
# Revenue per Dollar Spent       0.134328
# Revenue                              36
# Cost                                268
# Name: 56, dtype: object

# %% [markdown]
# The campaign that generated the least revenue per dollar spent is "**Rolling Bag**", with a revenue per dollar spent of approximately **\$0.13**, a total revenue of **\$36**, and a cost of **$268**.

# %% [markdown]
# #Vislualization

# %%
# Select the top 10 campaigns by revenue
top_10_campaigns = revenue_df.nlargest(10, 'Revenue')

# Plot the top 10 campaigns
plt.figure(figsize=(12, 6))
plt.bar(top_10_campaigns['Campaign'], top_10_campaigns['Revenue'], color='blue')
plt.xlabel('Campaign')
plt.ylabel('Revenue')
plt.title('Top 10 Campaigns by Revenue Generated')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Create a table for the top 10 campaigns by revenue, including their cost
top_10_campaigns_table = top_10_campaigns[['Campaign', 'Revenue', 'Cost']]
top_10_campaigns_table
# Out:
#         Campaign  Revenue  Cost
# 119      Satchel     4710   279
# 107         Tote     2262   288
# 108   Duffel Bag     2184   212
# 84          Tote     1940   226
# 97   Rolling Bag     1650   244
# 67    Travel Bag     1539   221
# 79    Travel Bag     1520   260
# 88         Pouch     1400   150
# 117         Tote     1330   277
# 85          Tote     1302   167

# %%
# Select the top 10 campaigns by revenue per conversion
top_10_rpc_campaigns = revenue_df.nlargest(10, 'Revenue per Conversion')

# Plot the top 10 campaigns by RPC
plt.figure(figsize=(12, 6))
plt.bar(top_10_rpc_campaigns['Campaign'], top_10_rpc_campaigns['Revenue per Conversion'], color='green')
plt.xlabel('Campaign')
plt.ylabel('Revenue per Conversion (RPC)')
plt.title('Top 10 Campaigns by Revenue per Conversion')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Create a table for the top 10 campaigns by RPC, including the number of conversions
top_10_rpc_table = top_10_rpc_campaigns[['Campaign', 'Revenue per Conversion', 'Conversions']]

top_10_rpc_table
# Out:
#            Campaign  Revenue per Conversion  Conversions
# 88            Pouch                   200.0            7
# 35       Duffel Bag                   196.0            3
# 78    Blue Backpack                   196.0            5
# 46            Purse                   194.0            1
# 84             Tote                   194.0           10
# 24  Yellow Backpack                   192.0            4
# 37            Pouch                   191.0            4
# 79       Travel Bag                   190.0            8
# 21       Travel Bag                   189.0            3
# 69            Purse                   188.0            3

# %%
# Select the top 10 campaigns by revenue per dollar spent
top_10_rpd_campaigns = revenue_df.nlargest(10, 'Revenue per Dollar Spent')

# Plot the top 10 campaigns by revenue per dollar spent
plt.figure(figsize=(12, 6))
plt.bar(top_10_rpd_campaigns['Campaign'], top_10_rpd_campaigns['Revenue per Dollar Spent'], color='orange')
plt.xlabel('Campaign')
plt.ylabel('Revenue per Dollar Spent')
plt.title('Top 10 Campaigns by Revenue per Dollar Spent')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Reuse the top_10_rpc_campaigns table
top_10_rpc_table
# Out:
#            Campaign  Revenue per Conversion  Conversions
# 88            Pouch                   200.0            7
# 35       Duffel Bag                   196.0            3
# 78    Blue Backpack                   196.0            5
# 46            Purse                   194.0            1
# 84             Tote                   194.0           10
# 24  Yellow Backpack                   192.0            4
# 37            Pouch                   191.0            4
# 79       Travel Bag                   190.0            8
# 21       Travel Bag                   189.0            3
# 69            Purse                   188.0            3

# %% [markdown]
# #Budget Allocation Strategy
#
# Maximize conversions while adhering to financial and performance constraints.
#
# ####Prioritize Low CPC Campaigns:
# * Campaigns with the lowest Cost Per Click (CPC) offer the best opportunity to maximize clicks for the budget.
#
# ####Follow Recommended Budget Limits:
# * Campaigns will be capped at their Recommended Budget Max to avoid diminishing returns and ensure efficiency.
#
# ####Ensure Channel Diversity:
# * Budgets will be distributed across a variety of channels (Display, Paid Social, etc.) to leverage different audience touchpoints while focusing on the most cost-effective campaigns.

# %% [markdown]
# To allocate the $14,000 budget effectively and maximize conversions using the Cost Per Acquisition (CPA) metric, we should:
#
# Prioritize Campaigns with Low CPA: Focus on campaigns that yield more conversions for every dollar spent.
# Consider Recommended Budget Max: Adhere to the suggested maximum budgets to avoid diminishing returns.
# Distribute Funds Strategically: Balance the allocation across high-performing and potential growth campaigns.
# Cap Allocation Per Campaign: Ensure no campaign exceeds the $3,000 limit.

# %%
# Prepare data for budget allocation by focusing on CPA and recommended max budget
campaigns_sorted_by_cpa = revenue_df.sort_values(by='CPA (Cost Per Conversion)').copy()

# Initialize variables
total_budget = 14000
max_per_campaign = 3000
allocation_plan = []

# Allocate budget to campaigns
for _, row in campaigns_sorted_by_cpa.iterrows():
    # Determine the amount to allocate based on remaining budget and constraints
    recommended_budget = min(row['Recommended Budget Max'], max_per_campaign)
    allocation = min(recommended_budget, total_budget)

    if allocation > 0:
        allocation_plan.append({
            'Channel': row['Source'],
            'Campaign': row['Campaign'],
            'Allocated Budget': allocation
        })
        total_budget -= allocation

    if total_budget <= 0:
        break

# Convert the allocation plan to a DataFrame for easy viewing
allocation_df = pd.DataFrame(allocation_plan)

allocation_df
# Out:
#        Channel       Campaign  Allocated Budget
# 0  Retargeting        Satchel            1344.0
# 1         Bing  Blue Backpack            1912.0
# 2    Instagram     Duffel Bag            1285.0
# 3         Bing        Satchel            2906.0
# 4    Clickbank          Pouch             744.0
# 5      Twitter  Blue Backpack            2155.0
# 6       Google    Rolling Bag            2911.0
# 7       Google     Duffel Bag             743.0

# %% [markdown]
# To help maximize revenue per dollar spent, we will need to choose performance upgrades within the constraints. Here’s the approach:
#
# ### Key Considerations:
# 1. **Overall Impact**: Upgrades that affect all campaigns have higher priority.
# 2. **Campaign Types**: Focus on upgrades benefiting high-revenue or high-cost campaign types.
# 3. **Cost Efficiency**: Maximize the benefits per dollar spent.

# %% [markdown]
# ### Recommendations:
# Based on the provided options and constraints:
#
# #### Option 1: **Calculate Customer Lifetime Value**
# - **Potential Effect**: +25% revenue per dollar spent for all campaigns.
# - **Cost**: $2,000.
# - **Reason**: Highest overall impact, benefiting all campaigns significantly.
#
# #### Option 2: **Conversion Rate Optimization Training**
# - **Potential Effect**: +10% revenue per dollar spent for all campaigns.
# - **Cost**: $1,000.
# - **Reason**: Strong impact at a low cost, applicable to all campaigns.
#
# #### Option 3: **Data Cleaning Training**
# - **Potential Effect**: +5% revenue per dollar spent for all campaigns.
# - **Cost**: $2,000.
# - **Reason**: Consistent improvement across all campaigns, stacks with other global upgrades.

# %% [markdown]
# #Results of the campaign

# %%
results_df = pd.read_csv('DMA-Campaign-Data-Revenue.csv')
results_df.head()
# Out:
#             Campaign Type         Source Campaign  Cost Per Impression  \
# Display       Retargeting        Satchel  $0.0010              1281347
# Paid Search          Bing  Blue Backpack  $0.0230                82126
# Paid Social     Instagram     Duffel Bag  $0.0100               126117
# Paid Search          Bing        Satchel  $0.0220               129353
# Affiliate       Clickbank          Pouch  $0.0130                54477
#
#             Impressions   CTR Clicks        CPC       Cost  Allocated Budget  \
# Display           0.53%  6791  $0.19  $1,281.35  $1,344.00               136
# Paid Search       2.47%  2029  $0.93  $1,888.89  $1,912.00               137
# Paid Social       1.47%  1854  $0.68  $1,261.17  $1,285.00                86
# Paid Search       2.44%  3156  $0.90  $2,845.78  $2,906.00               177
# Affiliate         1.02%   556  $1.27    $708.20    $744.00                43
#
#             Conversions CPA (Cost Per Conversion) Conversion Rate  \
# ...

# %% [markdown]
# #Summary of Results:
#
# The dataset evaluates the performance of various marketing campaigns, including Display, Paid Search, Paid Social, and Affiliate campaigns. Here's a summary of the key findings:
#
# **Cost and Budget Allocation**:
#    - Campaign budgets varied, with some campaigns like "**Paid Search - Satchel**" receiving higher allocations (e.g., **\$2,906**).
#    - Cost-per-impression (CPI) rates ranged from **\\$0.0010** (e.g., **Retargeting**) to **\$0.0230** (e.g., **Bing**).
#
# **Engagement Metrics**:
#    - **Click-Through Rate (CTR)**:
#      - **Display** campaigns generally had lower CTRs (e.g., **0.53%**) compared to **Paid Search** campaigns (up to **2.47%**).
#    - **Cost Per Click (CPC)**:
#      - CPC varied, with **Paid Search** campaigns averaging around **\\$0.90–$0.93**, while others like **Affiliate** campaigns reached **$1.27**.
#
# **Conversion Performance**:
#    - Conversion rates ranged widely, with **Affiliate** campaigns achieving the highest rate (**7.79%**), indicating strong targeting.
#    - Cost per conversion (CPA) was higher for campaigns like **Display** (**$226.67**) and lower for **Paid Search** (**\\$75.08**), suggesting more efficient acquisition in search-based campaigns.
#
# **Revenue and Profitability**:
#    - **Average Revenue Per Conversion**:
#      - **Paid Search and Paid Social** campaigns generated significant revenue per conversion, up to **$20,706.55**.
#    - **Profits and ROI**:
#      - Display campaigns showed substantial ROI (**605.91%**), indicating a highly profitable initiative.
#      - **Paid Social** campaigns also demonstrated strong profit growth (**634.20%**), leveraging lower CPC and higher engagement.
#
# **Margin**:
#    - Campaign margins ranged between **48%** (**Paid Social**) and **87%** (**Affiliate**), indicating diverse profitability levels.
#
# ### Key Insights:
# - **Display Campaigns**: Delivered significant ROI but had relatively low CTR and higher CPA.
# - **Paid Search**: Balanced performance with high conversion rates and reasonable CPA, contributing to steady revenue growth.
# - **Paid Social**: Achieved notable ROI and profits, leveraging moderate engagement and conversion metrics.
# - **Affiliate Campaigns**: Outperformed in conversion rates and margin percentage, showcasing efficient targeting and lower costs.

# %% [markdown]
# #Recommendations
#
# ###Focus on High-Performing Campaigns
# Allocate more budget to campaigns with the highest Revenue Per Dollar Spent (RPD) and Revenue Per Conversion (RPC). These campaigns are delivering the best returns and should be prioritized to maximize revenue.
#
# ###Optimize Underperforming Campaigns
# Analyze campaigns with low revenue and high costs to identify potential issues such as:
# * Poor targeting or creative execution.
# * High Cost Per Click (CPC) or low Conversion Rates (CR).
# * Implement changes like improving ad creatives, refining targeting, or optimizing bidding strategies.
#
# ###Improve Tracking and Attribution
# * Ensure accurate UTM tracking and robust attribution systems to capture the true impact of each campaign.
# * Invest in tools like Setup Attribution for better understanding of Display campaigns’ contributions.
#
# ##Next Steps:
# * Review the historical data in detail to validate these recommendations.
# * Allocate the advertising budget accordingly, reserving funds for key performance upgrades.
# * Schedule periodic reviews to assess the impact of implemented changes and iterate based on results.
